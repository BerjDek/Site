# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
#
# ...

# %%
data = [
    {
        "Study": "Study 1 (Chapter 3)",
        "Focus": "Demographic and motivational differences between participants in analog and digital citizen science projects (Mosquito Alert vs. Mückenatlas).",
        "Research Question Addressed": "How do the demographic profiles and motivations of participants differ between analog and digital citizen science initiatives?"
    },
    {
        "Study": "Study 2 (Chapter 4)",
        "Focus": "Investigation of regulatory focus orientations among Mosquito Alert participants and their influence on engagement patterns.",
        "Research Question Addressed": "How does regulatory focus (promotion vs. prevention) manifest among citizen science participants, and how does it influence engagement patterns?"
    },
    {
        "Study": "Study 3 (Chapter 5)",
        "Focus": "Experimental test of nudging interventions framed by regulatory focus to enhance engagement and retention.",
        "Research Question Addressed": "Can targeted interventions (such as nudging) framed according to participants' regulatory focus enhance engagement and retention in citizen science initiatives?"
    }
]

data
# Out:
# [{'Study': 'Study 1 (Chapter 3)',
#   'Focus': 'Demographic and motivational differences between participants in analog and digital citizen science projects (Mosquito Alert vs. Mückenatlas).',
#   'Research Question Addressed': 'How do the demographic profiles and motivations of participants differ between analog and digital citizen science initiatives?'},
#  {'Study': 'Study 2 (Chapter 4)',
#   'Focus': 'Investigation of regulatory focus orientations among Mosquito Alert participants and their influence on engagement patterns.',
#   'Research Question Addressed': 'How does regulatory focus (promotion vs. prevention) manifest among citizen science participants, and how does it influence engagement patterns?'},
#  {'Study': 'Study 3 (Chapter 5)',
#   'Focus': 'Experimental test of nudging interventions framed by regulatory focus to enhance engagement and retention.',
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                  Study                                              Focus  \
# 0  Study 1 (Chapter 3)  Demographic and motivational differences betwe...
# 1  Study 2 (Chapter 4)  Investigation of regulatory focus orientations...
# 2  Study 3 (Chapter 5)  Experimental test of nudging interventions fra...
#
#                          Research Question Addressed
# 0  How do the demographic profiles and motivation...
# 1  How does regulatory focus (promotion vs. preve...
# 2  Can targeted interventions (such as nudging) f...

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\BerjD\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.0 MB 10.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.0 MB 9.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 10.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------------------------------- - 2.1/2.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 11.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
# ...

# %%
# Adjust figure size
fig, ax = plt.subplots(figsize=(12, 3))  # Change size as needed (width, height)

# Create the table
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center')

# Adjust font size and column width
table.auto_set_font_size(False)
table.set_fontsize(10)
table.auto_set_column_width(col=list(range(len(df.columns))))

# %%
# %pip install tabulate

from tabulate import tabulate

# Create a scientific table from the dataframe
table = tabulate(df, headers='keys', tablefmt='grid')
print(table)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# +----+---------------------+------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    | Study               | Focus                                                                                                                                          | Research Question Addressed                                                                                                                                      |
# ...
